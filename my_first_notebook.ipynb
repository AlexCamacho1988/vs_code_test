# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

plt.scatter(x,y)

# %%
print('Kamehameha')
# Out:
# Kamehameha

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 10]

plt.scatter(x,y)
